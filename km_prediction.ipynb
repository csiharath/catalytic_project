# %% [markdown]
# # Import libraries

# %%
import cobra
import requests
import pandas as pd
import numpy

# %%
add_kegg_id = False

# %% [markdown]
# # Add KEGG ID in model

# %% [markdown]
# Note : CSV must contain one column 'Reaction name', one 'KEGG reaction ID' and one 'Gene name'

# %%
if add_kegg_id:
    model_to_improve = cobra.io.read_sbml_model("Models/ccm_ross.xml")

# %%
# metabolites_list = [metabolite.id for metabolite in model.metabolites]

# %%
# metabolites_list

# %%
df_react = pd.read_csv("tab_reactions.csv", sep=";")
# df_react = df_react.dropna()
df_react = df_react.set_index('Reaction name')
df_react
# Out:
#               KEGG reaction ID
# Reaction name
# pts                     RPTSsy  \
# pgi                     R02740
# pfk                     R04779
# fbp                     R00762
# ald                     R01070
# tim                     R01015
# gap                     R01061
# pgk                     R01512
# pgm                     R01518
# pgh                     R00658
# pyk                     R00200
# pps                     R00199
# zwf                     R00835
# glh                     R02035
# pgd                     R01528
# rpe                     R01529
# rpi                     R01056
# tkt1                    R01641
# tal                     R08575
# tkt2                    R01067
# edd                     R02036
# eda                     R05605
# pfl                     R00212
# pdh                     R00209
# csn                     R00351
# acn                     R01324
# icd                     R00709
# kgd                     R08549
# scs                     R00405
# sdh                     R02164
# frd                     R02164
# fum                     R01082
# mdh                     R00342
# ppc                     R00345
# me                      R00214
# ppck                    R00341
# ldh                     R00703
# ada                     R00228
# adh                     R00754
# pta                     R00230
# ack                     R00315
# nadh-dh                 R11945
# cytbd                   R11335
# atp-synth                  NaN
# nad-thd                 R00112
# ex-etoh                    NaN
# ex-ace                     NaN
# ex-lac                     NaN
# ex-suc                     NaN
# ex-for                     NaN
# ex-co2                     NaN
#
#                                                        Gene name
# Reaction name
# pts                                               ptsG,ptsH,ptsI
# pgi                                                          pgi
# pfk                                                         pfkA
# fbp                                                          fbp
# ald                                                         fbaA
# tim                                                         tpiA
# gap                                                   gapA, gapB
# pgk                                                          pgk
# pgm                                                    gpml/pgml
# pgh                                                          eno
# pyk                                                         pykF
# pps                                                          pps
# zwf                                                          zwk
# glh                                                          pgl
# pgd                                                          gnd
# rpe                                                          rpe
# rpi                                                         rpiA
# tkt1                                                        tktA
# tal                                                         talA
# tkt2                                                        tktB
# edd                                                          edd
# eda                                                          eda
# pfl                                               pflD,pflB,ybiW
# pdh                                               aceE,aceF,lpdA
# csn                                                         gltA
# acn                                                    acnA,acnB
# icd                                                          icd
# kgd                                               sucA,sucB,lpdA
# scs                                                    sucC,sucD
# sdh                                          sdhD,sdhA,sdhB,sdhC
# frd                                                    frdA,frdB
# fum                                fumA,fumD,fumD,fumE,fumC,fumB
# mdh                                                          mdh
# ppc                                                          ppc
# me                                                          maeA
# ppck                                                        pckA
# ldh                                                         lldD
# ada                                                         acdh
# adh                                                         adhE
# pta                                                          pta
# ack                                                          ack
# nadh-dh        nuoA,nuoH,nuoJ,nuoL,nuoM,nuoN,nuoI,nuoG,nuoF,n...
# cytbd                                        cyoD,cyoA,cyoB,cyoC
# atp-synth           atpF,atpA,atpH,atpG,atpE,atpC,atpI,atpB,atpD
# nad-thd                                                     sthA
# ex-etoh                                                diffusion
# ex-ace                                                 ActP/staP
# ex-lac                                               lldP (GlcA)
# ex-suc                                                      satP
# ex-for                                                      focA
# ex-co2                                                 diffusion

# %%
def add_kegg_id_to_model(model, dataframe_react):
    for reaction in model.reactions:
        print(reaction.id)
        try :
            if dataframe_react.loc[reaction.id]['KEGG reaction ID'] != "NaN":
                reaction.notes = {"kegg_id": dataframe_react.loc[reaction.id]['KEGG reaction ID']}
            else:
                print(dataframe_react.loc[reaction.id]['KEGG reaction ID'])
        except :
            print("no")

# %%
if add_kegg_id:
    add_kegg_id_to_model(model_to_improve, df_react)
    cobra.io.write_sbml_model(model_to_improve, filename="model_file.xml")

# %% [markdown]
# # Get AA sequence of enzyme

# %%
new_model = cobra.io.read_sbml_model("Models/model_ccm_2.xml")
new_model
# Out:
# <Model ccm_ross_xml at 0x22f397b44c0>

# %% [markdown]
# ### Add gene reaction rule to the model
# Takes as input a dictionary that links the reaction IDs of the model to the gene IDs.

# %%
data = pd.read_csv("tab_reactions.csv", sep=",")
model = cobra.io.read_sbml_model("./model_ccm_2.xml")

# %%
from collections import defaultdict
reaction2genes = defaultdict(list)
for i in range(len(data)):
    reaction_name_tmp = data.loc[i,"Reaction name"]

    if not isinstance(reaction_name_tmp,str) :
        pass
    else:
        reaction_name = reaction_name_tmp

    if str(data.loc[i,"Gene name"]) != "nan":
        if "?" in data.loc[i,"Gene name"]:
            continue
        elif "/" in data.loc[i,"Gene name"]:
            genes = data.loc[i,"Gene name"].split("/")
            print(genes, type(genes))
            for gene_name in genes :
                reaction2genes[reaction_name].append(gene_name)
        elif "(" in data.loc[i,"Gene name"] :
            gene = data.loc[i,"Gene name"].split("(")[0].strip(" ")
            reaction2genes[reaction_name].append(gene)
        else:
            reaction2genes[reaction_name].append(data.loc[i,"Gene name"])
    else : continue
# Out:
# ['gpml', 'pgml'] <class 'list'>
# ['ActP', 'staP'] <class 'list'>

# %%
for reac_id, genes in reaction2genes.items():
    try:

        reac_obj = model.reactions.get_by_id(reac_id)
        gene_reaction_rule = " or ".join(genes)
        reac_obj.gene_reaction_rule = gene_reaction_rule

    except KeyError:
        continue

# %%
enzyme_list = [(enzyme.id, enzyme.notes['kegg_id']) for enzyme in model.reactions if 'kegg_id' in enzyme.notes]

# %%
reac = model.reactions.get_by_id("tim")
"tpiA" in [g.id for g in reac.genes]
# Out:
# True

# %%
def find_compounds_AAseq(list_of_enzymes, dict_seq = {}):
    for enzyme in list_of_enzymes:
        print(f"Looking for compounds and AA sequence of {enzyme[0]}:{enzyme[1]}")
        aa = False
        ortho = False
        ko = False
        seq = ""
        url = "http://rest.kegg.jp/get/"

        # First request to get list of compounds and the KEGG Orthology ID from the KEGG ID
        r1 = requests.get(url=url+enzyme[1])

        if r1.status_code==200:
            # The content is one long string: splitting with \n to iter on every line
            info = str(r1.content).split('\'')[1].split('\\n')

            for line in info:

                # The line with all compounds:
                if 'EQUATION' in line:
                    compounds = [c for c in line.split() if 'C' in c]

                # Line(s) with KEGG Orthology ID to test
                elif 'ORTHOLOGY' in line or ortho:
                    # print(line)

                    if ortho:
                        id = line.split()[0]
                        if id == 'DBLINKS' or id =='///':
                            ko = True
                            print(f"\n[!]KEGG ID {enzyme[1]} has no corresponding KEGG Orthology ID for organism ece\n\n===\n")
                            break
                    else:
                        id = line.split()[1]
                        ortho = True

                    # Second request to get CDS ID from KEGG ORthology ID
                    r2 = requests.get(url=url+id)

                    if r2.status_code==200:
                        info = str(r2.content).split('\'')[1].split('\\n')

                        for line in info:

                            # Line corresponding to the organism target (e.coli)
                            if 'ECO:' in line:
                                ############# modifier pour verifier les sous unites #############
                                
                                #For each line, we select the ones corresponding to the organism's ID
                                #And store in a list of tuples the KEGG gene IDs and corresponding gene names.
                                #We can then use the gene names to check if the KEGG IDs are the right ones.

                                line_list = line.split(" ")
                                start_index = line_list.index("ECO:")
                                idZ_list = line_list[start_index+1:]
                                idZ_gID = [(idZ, gID) for idZ, gID in zip([elem.split('(')[0] for elem in idZ_list],\
                                                                           [elem.split('(')[1].strip(')') for elem in idZ_list])]
                                
                                #Gene ID comparison between the KEGG response and the model's gene names.
                                for idZ, gID in idZ_gID:
                                    reac_obj = model.reactions.get_by_id(enzyme[0])

                                    if gID.lower() in [str(g.id).lower() for g in reac_obj.genes]:
                                        print(f"\n[>]Found {gID} gene id in reaction {reac_obj.name}. Adding its aa sequence to the dictionary.\n\n===\n")
                                    
                                        # Third request to get AA sequence from CDS ID
                                        r3 = requests.get(url=url+"eco:"+idZ)
                                    

                                        if r3.status_code==200:
                                            info = str(r3.content).split('\'')[1].split('\\n')

                                            for line in info:
                                                if 'AASEQ' in line:
                                                    aa = True
                                                    
                                                elif 'NTSEQ' in line:
                                                    break

                                                elif aa:
                                                    seq += line.split()[0]
                                    else:
                                        continue
                                break

                                    

                if seq != "":
                    dict_seq[enzyme[1]] = (compounds, seq)
                    break
                elif ko:
                    break
                elif ortho:
                    aa = False
                    print(f"Trying another KEGG Orthology ID for {enzyme[0]}:{enzyme[1]}")
        

        else: 
            print(f"\n[!]KEGG ID {enzyme[1]} is not found in kegg.\n\n===\n")

    return dict_seq

# %%
# Takes 6min10 - 4min5
dict_km_parameters = find_compounds_AAseq(enzyme_list)
# dict_km_parameters
# Out:
# Looking for compounds and AA sequence of ack:R00315
# Trying another KEGG Orthology ID for ack:R00315
#
# [!]KEGG ID R00315 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of acn:R01324
#
# [>]Found acnA gene id in reaction acn. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of ada:R00228
# Trying another KEGG Orthology ID for ada:R00228
# Trying another KEGG Orthology ID for ada:R00228
# Trying another KEGG Orthology ID for ada:R00228
# Trying another KEGG Orthology ID for ada:R00228
# Trying another KEGG Orthology ID for ada:R00228
#
# [!]KEGG ID R00228 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of adh:R00754
# Trying another KEGG Orthology ID for adh:R00754
# Trying another KEGG Orthology ID for adh:R00754
# Trying another KEGG Orthology ID for adh:R00754
#
# [>]Found adhE gene id in reaction adh. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of ald:R01070
# Trying another KEGG Orthology ID for ald:R01070
# Trying another KEGG Orthology ID for ald:R01070
#
# [>]Found fbaA gene id in reaction ald. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of csn:R00351
#
# [>]Found gltA gene id in reaction csn. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of cytbd:R11335
#
# [>]Found cyoA gene id in reaction cytbd. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of eda:R05605
#
# [>]Found eda gene id in reaction eda. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of edd:R02036
#
# [>]Found edd gene id in reaction edd. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of fbp:R00762
# Trying another KEGG Orthology ID for fbp:R00762
# Trying another KEGG Orthology ID for fbp:R00762
# Trying another KEGG Orthology ID for fbp:R00762
#
# [>]Found fbp gene id in reaction fbp. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
# Trying another KEGG Orthology ID for frd:R02164
#
# [>]Found frdA gene id in reaction frd. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of fum:R01082
#
# [>]Found fumD gene id in reaction fum. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of gap:R01061
#
# [>]Found gapA gene id in reaction gap. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of glh:R02035
# Trying another KEGG Orthology ID for glh:R02035
#
# [>]Found pgl gene id in reaction glh. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of icd:R00709
# Trying another KEGG Orthology ID for icd:R00709
# Trying another KEGG Orthology ID for icd:R00709
#
# [!]KEGG ID R00709 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of kgd:R08549
#
# [>]Found sucA gene id in reaction kgd. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of ldh:R00703
# Trying another KEGG Orthology ID for ldh:R00703
#
# [!]KEGG ID R00703 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of mdh:R00342
#
# [>]Found mdh gene id in reaction mdh. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of me:R00214
#
# [>]Found maeA gene id in reaction me. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of pdh:R00209
# Trying another KEGG Orthology ID for pdh:R00209
# Trying another KEGG Orthology ID for pdh:R00209
#
# [>]Found aceE gene id in reaction pdh. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of pfk:R04779
#
# [>]Found pfkA gene id in reaction pfk. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of pfl:R00212
#
# [>]Found pflB gene id in reaction pfl. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of pgd:R01528
#
# [>]Found gnd gene id in reaction pgd. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of pgh:R00658
#
# [>]Found eno gene id in reaction pgh. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of pgi:R02740
# Trying another KEGG Orthology ID for pgi:R02740
# Trying another KEGG Orthology ID for pgi:R02740
# Trying another KEGG Orthology ID for pgi:R02740
# Trying another KEGG Orthology ID for pgi:R02740
#
# [!]KEGG ID R02740 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of pgk:R01512
#
# [>]Found pgk gene id in reaction pgk. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of pgm:R01518
# Trying another KEGG Orthology ID for pgm:R01518
# Trying another KEGG Orthology ID for pgm:R01518
# Trying another KEGG Orthology ID for pgm:R01518
# Trying another KEGG Orthology ID for pgm:R01518
# Trying another KEGG Orthology ID for pgm:R01518
#
# [!]KEGG ID R01518 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of ppc:R00345
#
# [>]Found ppc gene id in reaction ppc. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of ppck:R00341
# Trying another KEGG Orthology ID for ppck:R00341
#
# [!]KEGG ID R00341 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of pta:R00230
# Trying another KEGG Orthology ID for pta:R00230
# Trying another KEGG Orthology ID for pta:R00230
#
# [>]Found pta gene id in reaction pta. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of pts:RPTSsy
#
# [!]KEGG ID RPTSsy is not found in kegg.
#
# ===
#
# Looking for compounds and AA sequence of pyk:R00200
#
# [>]Found pykF gene id in reaction pyk. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of rpe:R01529
#
# [>]Found rpe gene id in reaction rpe. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of rpi:R01056
#
# [>]Found rpiA gene id in reaction rpi. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of scs:R00405
#
# [>]Found sucD gene id in reaction scs. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of sdh:R02164
# Trying another KEGG Orthology ID for sdh:R02164
# Trying another KEGG Orthology ID for sdh:R02164
# Trying another KEGG Orthology ID for sdh:R02164
# Trying another KEGG Orthology ID for sdh:R02164
# Trying another KEGG Orthology ID for sdh:R02164
#
# [>]Found sdhA gene id in reaction sdh. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of tal:R08575
# Looking for compounds and AA sequence of tim:R01015
#
# [>]Found tpiA gene id in reaction tim. Adding its aa sequence to the dictionary.
#
# ===
#
# Looking for compounds and AA sequence of tkt1:R01641
# Trying another KEGG Orthology ID for tkt1:R01641
#
# [!]KEGG ID R01641 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of tkt2:R01067
# Trying another KEGG Orthology ID for tkt2:R01067
#
# [!]KEGG ID R01067 has no corresponding KEGG Orthology ID for organism ece
#
# ===
#
# Looking for compounds and AA sequence of zwf:R00835
# Trying another KEGG Orthology ID for zwf:R00835
#
# [!]KEGG ID R00835 has no corresponding KEGG Orthology ID for organism ece
#
# ===

# %%
list_substrat = []
list_enzyme = []

for enzyme in dict_km_parameters:
    for compound in dict_km_parameters[enzyme][0]:
        list_substrat.append(compound)
        list_enzyme.append(dict_km_parameters[enzyme][1])

# %%
len(list_enzyme)
# Out:
# 140

# %%
len(list_substrat)
# Out:
# 140

# %%
unique_compounds = numpy.unique(list_substrat).tolist()
# unique_compounds

# %%
dict_compounds = {}

for compound in unique_compounds:
    url = "http://rest.kegg.jp/get/"
    r = requests.get(url=url+compound)
    car = str(r.content)[1]
    info = str(r.content).split(car)[1].split('\\n')
    dict_compounds[compound] = info[1].split()[1].split(';')[0]

# %%
dict_compounds
# Out:
# {'C00001': 'H2O',
#  'C00002': 'ATP',
#  'C00003': 'NAD+',
#  'C00004': 'NADH',
#  'C00005': 'NADPH',
#  'C00006': 'NADP+',
#  'C00007': 'Oxygen',
#  'C00008': 'ADP',
#  'C00009': 'Orthophosphate',
#  'C00010': 'CoA',
#  'C00011': 'CO2',
#  'C00022': 'Pyruvate',
#  'C00024': 'Acetyl-CoA',
#  'C00026': '2-Oxoglutarate',
#  'C00033': 'Acetate',
#  'C00036': 'Oxaloacetate',
#  'C00042': 'Succinate',
#  'C00058': 'Formate',
#  'C00074': 'Phosphoenolpyruvate',
#  'C00080': 'H+',
#  'C00084': 'Acetaldehyde',
#  'C00085': 'D-Fructose',
#  'C00091': 'Succinyl-CoA',
#  'C00092': 'D-Glucose',
#  'C00111': 'Glycerone',
#  'C00117': 'D-Ribose',
#  'C00118': 'D-Glyceraldehyde',
#  'C00122': 'Fumarate',
#  'C00149': '(S)-Malate',
#  'C00158': 'Citrate',
#  'C00197': '3-Phospho-D-glycerate',
#  'C00199': 'D-Ribulose',
#  'C00227': 'Acetyl',
#  'C00231': 'D-Xylulose',
#  'C00236': '3-Phospho-D-glyceroyl',
#  'C00311': 'Isocitrate',
#  'C00345': '6-Phospho-D-gluconate',
#  'C00354': 'D-Fructose',
#  'C00390': 'Ubiquinol',
#  'C00399': 'Ubiquinone',
#  'C00469': 'Ethanol',
#  'C00631': '2-Phospho-D-glycerate',
#  'C01236': 'D-Glucono-1,5-lactone',
#  'C04442': '2-Dehydro-3-deoxy-6-phospho-D-gluconate',
#  'C05345': 'beta-D-Fructose',
#  'C05378': 'beta-D-Fructose',
#  'C15602': 'Quinone',
#  'C15603': 'Hydroquinone'}

# %%
import pickle

# %%
with open("enzyme.p", "wb") as e:
    enzymes = pickle.dump(list_enzyme, e)

with open("substrat.p", "wb") as s:
    substrats = pickle.dump(list_substrat, s)

with open("compound.p", "wb") as c:
    dict_compounds = pickle.dump(dict_compounds, c)

# %% [markdown]
# ---
# # Omnipath tests

# %%
import omnipath

# %%
help(omnipath)
# Out:
# Help on package omnipath:
#
# NAME
#     omnipath
#
# PACKAGE CONTENTS
#     _core (package)
#     _misc (package)
#     constants (package)
#     interactions
#     requests
#
# DATA
#     __email__ = 'turei.denes@gmail.com'
#     __full_version__ = '1.0.6'
#     __maintainer__ = 'Michal Klein, Dénes Türei'
#     __server_version__ = '0.14.46'
#     options = Options(url='https://omnipathdb.org', license=No...rue, num_...
#
# VERSION
#     1.0.6
#
# AUTHOR
#     Michal Klein, Dénes Türei
#
# FILE
#     /home/jmuller/miniconda3/envs/rba/lib/python3.10/site-packages/omnipath/__init__.py
